# %% [markdown]
# # Problem 1 : Data Preparation
# Download the dataset train.csv and the associated text file data_description.txt posted with this Exercise. The dataset
# and description are collected from Kaggle. You may also want to download the files directly from the Kaggle Competition
# (Login > Go to “Data” > “Download All”). Either way, read the competition description to get an idea about the task.
#
# Source : Kaggle Competition : House Prices : https://www.kaggle.com/c/house-prices-advanced-regression-techniques

# %% [markdown]
# a) Import the “train.csv” data you downloaded (either from NTU Learn or Kaggle) in Jupyter Notebook.

# %%
import pandas as pd

trainData = pd.read_csv('train.csv', header = 0)
trainData.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %% [markdown]
# b) What are the data types (“dtypes”) – int64/float64/object – of the variables (columns) in the dataset?

# %%
trainData.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %% [markdown]
# c) Create a new Pandas DataFrame consisting of only the variables (columns) of type Integer (int64).

# %%
trainData_Integer = trainData.select_dtypes(include = 'int64')
trainData_Integer.dtypes.sort_index()
#trainData_Integer
# Out:
# 1stFlrSF         int64
# 2ndFlrSF         int64
# 3SsnPorch        int64
# BedroomAbvGr     int64
# BsmtFinSF1       int64
# BsmtFinSF2       int64
# BsmtFullBath     int64
# BsmtHalfBath     int64
# BsmtUnfSF        int64
# EnclosedPorch    int64
# Fireplaces       int64
# FullBath         int64
# GarageArea       int64
# GarageCars       int64
# GrLivArea        int64
# HalfBath         int64
# Id               int64
# KitchenAbvGr     int64
# LotArea          int64
# LowQualFinSF     int64
# MSSubClass       int64
# MiscVal          int64
# MoSold           int64
# OpenPorchSF      int64
# OverallCond      int64
# OverallQual      int64
# PoolArea         int64
# SalePrice        int64
# ScreenPorch      int64
# TotRmsAbvGrd     int64
# TotalBsmtSF      int64
# WoodDeckSF       int64
# YearBuilt        int64
# YearRemodAdd     int64
# YrSold           int64
# dtype: object

# %% [markdown]
# d) Open the “data_description.txt” file you downloaded (either from NTU Learn or Kaggle) in Wordpad.
# Read the description for each variable carefully and try to identify the “actual” Numeric variables.
# Categorical variables are often “encoded” as Numeric variables for easy representation. Spot them.

# %% [markdown]
# MSSubClass, MoSold, YrSold, Id, YearBuilt, YearRemodAdd

# %% [markdown]
# e) Drop non-Numeric variables from the DataFrame to have a clean DataFrame with Numeric variables.

# %%
CLEAN_trainData_Integer = trainData_Integer.drop(['MSSubClass', 'MoSold', 'YrSold', 'Id', 'YearBuilt', 'YearRemodAdd' ], axis=1)
CLEAN_trainData_Integer
# Out:
#       LotArea  OverallQual  OverallCond  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0        8450            7            5         706           0        150
# 1        9600            6            8         978           0        284
# 2       11250            7            5         486           0        434
# 3        9550            7            5         216           0        540
# 4       14260            8            5         655           0        490
# ...       ...          ...          ...         ...         ...        ...
# 1455     7917            6            5           0           0        953
# 1456    13175            6            6         790         163        589
# 1457     9042            7            9         275           0        877
# 1458     9717            5            6          49        1029          0
# 1459     9937            5            6         830         290        136
#
#       TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  ...  GarageCars  \
# 0             856       856       854             0  ...           2
# 1            1262      1262         0             0  ...           2
# 2             920       920       866             0  ...           2
# 3             756       961       756             0  ...           3
# 4            1145      1145      1053             0  ...           3
# ...           ...       ...       ...           ...  ...         ...
# 1455          953       953       694             0  ...           2
# 1456         1542      2073         0             0  ...           2
# 1457         1152      1188      1152             0  ...           1
# 1458         1078      1078         0             0  ...           1
# 1459         1256      1256         0             0  ...           1
#
#       GarageArea  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0            548           0           61              0          0
# 1            460         298            0              0          0
# 2            608           0           42              0          0
# 3            642           0           35            272          0
# 4            836         192           84              0          0
# ...          ...         ...          ...            ...        ...
# 1455         460           0           40              0          0
# 1456         500         349            0              0          0
# 1457         252           0           60              0          0
# 1458         240         366            0            112          0
# 1459         276         736           68              0          0
#
#       ScreenPorch  PoolArea  MiscVal  SalePrice
# 0               0         0        0     208500
# 1               0         0        0     181500
# 2               0         0        0     223500
# 3               0         0        0     140000
# 4               0         0        0     250000
# ...           ...       ...      ...        ...
# 1455            0         0        0     175000
# 1456            0         0        0     210000
# 1457            0         0     2500     266500
# 1458            0         0        0     142125
# 1459            0         0        0     147500
#
# [1460 rows x 29 columns]

# %% [markdown]
# # Problem 2 : Statistical Summary
# Now that you have a “clean” DataFrame with only Numeric variables, we can safely perform standard statistics.

# %% [markdown]
# a) Find the Summary Statistics (Mean, Median, Quartiles etc.) of SalePrice from the Numeric DataFrame.

# %%
SalePriceStats = CLEAN_trainData_Integer.SalePrice
SalePriceStats.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# b) Visualize the summary statistics and distribution of SalePrice using standard Box-Plot, Histogram, KDE.

# %%
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot

# Set up matplotlib figure with three subplots
f, axes = plt.subplots(1, 3, figsize=(24, 6))

# Plot the basic uni-variate figures for HP
sb.boxplot(data = SalePriceStats, orient = "h", ax = axes[0])
sb.histplot(data = SalePriceStats, ax = axes[1])
sb.kdeplot(data = SalePriceStats, ax = axes[2])
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>

# %% [markdown]
# c) Find the Summary Statistics (Mean, Median, Quartiles etc) of LotArea from the Numeric DataFrame.

# %%
LotAreaStats = CLEAN_trainData_Integer.LotArea
LotAreaStats.describe()
# Out:
# count      1460.000000
# mean      10516.828082
# std        9981.264932
# min        1300.000000
# 25%        7553.500000
# 50%        9478.500000
# 75%       11601.500000
# max      215245.000000
# Name: LotArea, dtype: float64

# %% [markdown]
# d) Visualize the summary statistics and distribution of LotArea using standard Box-Plot, Histogram, KDE.

# %%
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot

# Set up matplotlib figure with three subplots
f, axes = plt.subplots(3, 1, figsize=(24, 24))

# Plot the basic uni-variate figures for HP
sb.boxplot(data = SalePriceStats, orient = "h", ax = axes[0])
sb.histplot(data = SalePriceStats, ax = axes[1])
sb.kdeplot(data = SalePriceStats, ax = axes[2])
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>

# %% [markdown]
# e) Plot SalePrice (y-axis) vs LotArea (x-axis) using jointplot and find the Correlation between the two.

# %%
jointData = pd.concat([SalePriceStats, LotAreaStats], axis = 1).reindex(SalePriceStats.index)
jointData
# Out:
#       SalePrice  LotArea
# 0        208500     8450
# 1        181500     9600
# 2        223500    11250
# 3        140000     9550
# 4        250000    14260
# ...         ...      ...
# 1455     175000     7917
# 1456     210000    13175
# 1457     266500     9042
# 1458     142125     9717
# 1459     147500     9937
#
# [1460 rows x 2 columns]

# %%
sb.jointplot(data = jointData, x = "LotArea", y = "SalePrice", height = 12)

# %%
jointData.corr()
sb.heatmap(jointData.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# You can say that lot area will have no effect on sale price since it is only 0.26

# %% [markdown]
# # Bonus
# Create a new Pandas DataFrame consisting of all variables (columns) of type Integer (int64) or Float (float64).

# %%
import pandas as pd

trainData = pd.read_csv('train.csv', header = 0)
trainData_Number = trainData.select_dtypes(include = ['int64', 'float64'])
trainData_Number.dtypes.sort_index()
#trainData_Number
# Out:
# 1stFlrSF           int64
# 2ndFlrSF           int64
# 3SsnPorch          int64
# BedroomAbvGr       int64
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# BsmtUnfSF          int64
# EnclosedPorch      int64
# Fireplaces         int64
# FullBath           int64
# GarageArea         int64
# GarageCars         int64
# GarageYrBlt      float64
# GrLivArea          int64
# HalfBath           int64
# Id                 int64
# KitchenAbvGr       int64
# LotArea            int64
# LotFrontage      float64
# LowQualFinSF       int64
# MSSubClass         int64
# MasVnrArea       float64
# MiscVal            int64
# MoSold             int64
# OpenPorchSF        int64
# OverallCond        int64
# OverallQual        int64
# PoolArea           int64
# SalePrice          int64
# ScreenPorch        int64
# TotRmsAbvGrd       int64
# TotalBsmtSF        int64
# WoodDeckSF         int64
# YearBuilt          int64
# YearRemodAdd       int64
# YrSold             int64
# dtype: object

# %% [markdown]
# Read the description for each variable carefully and try to identify the “actual” Numeric variables in the data.

# %% [markdown]
# 'MSSubClass', 'MoSold', 'YrSold', 'Id', 'YearBuilt', 'YearRemodAdd', 'GarageYrBlt'

# %% [markdown]
# Drop non-Numeric variables from the DataFrame to have a clean DataFrame with only the Numeric variables.

# %%
DROP_trainData_Number = trainData_Number.drop(['MSSubClass', 'MoSold', 'YrSold', 'Id', 'YearBuilt', 'YearRemodAdd', 'GarageYrBlt'], axis=1)
DROP_trainData_Number
# Out:
#       LotFrontage  LotArea  OverallQual  OverallCond  MasVnrArea  BsmtFinSF1  \
# 0            65.0     8450            7            5       196.0         706
# 1            80.0     9600            6            8         0.0         978
# 2            68.0    11250            7            5       162.0         486
# 3            60.0     9550            7            5         0.0         216
# 4            84.0    14260            8            5       350.0         655
# ...           ...      ...          ...          ...         ...         ...
# 1455         62.0     7917            6            5         0.0           0
# 1456         85.0    13175            6            6       119.0         790
# 1457         66.0     9042            7            9         0.0         275
# 1458         68.0     9717            5            6         0.0          49
# 1459         75.0     9937            5            6         0.0         830
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  ...  GarageCars  \
# 0              0        150          856       856  ...           2
# 1              0        284         1262      1262  ...           2
# 2              0        434          920       920  ...           2
# 3              0        540          756       961  ...           3
# 4              0        490         1145      1145  ...           3
# ...          ...        ...          ...       ...  ...         ...
# 1455           0        953          953       953  ...           2
# 1456         163        589         1542      2073  ...           2
# 1457           0        877         1152      1188  ...           1
# 1458        1029          0         1078      1078  ...           1
# 1459         290        136         1256      1256  ...           1
#
#       GarageArea  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0            548           0           61              0          0
# 1            460         298            0              0          0
# 2            608           0           42              0          0
# 3            642           0           35            272          0
# 4            836         192           84              0          0
# ...          ...         ...          ...            ...        ...
# 1455         460           0           40              0          0
# 1456         500         349            0              0          0
# 1457         252           0           60              0          0
# 1458         240         366            0            112          0
# 1459         276         736           68              0          0
#
#       ScreenPorch  PoolArea  MiscVal  SalePrice
# 0               0         0        0     208500
# 1               0         0        0     181500
# 2               0         0        0     223500
# 3               0         0        0     140000
# 4               0         0        0     250000
# ...           ...       ...      ...        ...
# 1455            0         0        0     175000
# 1456            0         0        0     210000
# 1457            0         0     2500     266500
# 1458            0         0        0     142125
# 1459            0         0        0     147500
#
# [1460 rows x 31 columns]

# %% [markdown]
# Plot SalePrice vs each of the Numeric variables you identified to understand their correlation or dependence.

# %%
import matplotlib.pyplot as plt

f = plt.figure(figsize=(24, 24))
sb.heatmap(DROP_trainData_Number.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <AxesSubplot:>
